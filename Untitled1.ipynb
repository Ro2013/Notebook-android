# %% [markdown]
# <a href="https://colab.research.google.com/github/Ro2013/Notebook-android/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===== 1️⃣ 安裝桌面環境與 VNC =====
# !apt update
# !apt install -y xfce4 xfce4-goodies tightvncserver wget unzip jq

# ===== 2️⃣ 安裝 noVNC =====
# !wget -q https://github.com/novnc/noVNC/archive/refs/heads/master.zip
# !unzip -q master.zip

# ===== 3️⃣ 掛載 Google Drive =====
from google.colab import drive
drive.mount('/content/drive')

# ===== 4️⃣ 匯入檔案到容器（你已手動建立 AndroidVM）=====
# !cp -r /content/drive/MyDrive/AndroidVM /content/ || true

# ===== 5️⃣ 設定 USER 環境變數（避免 vncserver 報錯）=====
import os
os.environ['USER'] = 'colab'

# ===== 6️⃣ 非互動設定 VNC 密碼（解決「密碼太短 / 卡死」）=====
# !mkdir -p ~/.vnc
# !echo "123456" | vncpasswd -f > ~/.vnc/passwd
# !chmod 600 ~/.vnc/passwd

# ===== 7️⃣ 啟動 VNC server（不再詢問密碼）=====
# !vncserver -kill :1 >/dev/null 2>&1 || true
# !vncserver :1 -geometry 1280x720 -depth 24

# ===== 8️⃣ 啟動 noVNC（新版，沒有 launch.sh）=====
# %cd /content/noVNC-master
# !nohup ./utils/novnc_proxy --vnc localhost:5901 --listen 0.0.0.0:6080 &

# ===== 9️⃣ 等待 noVNC 啟動 =====
import time
time.sleep(5)

# ===== 🔟 安裝 ngrok 3 =====
# !wget -q https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar xzf ngrok-v3-stable-linux-amd64.tgz

# ===== 1️⃣1️⃣ 設定 ngrok token =====
# !./ngrok config add-authtoken 37SR7WypDaMORVh1v0kfoTuJv3c_652p8z5XyAujnMp3HYmzc

# ===== 1️⃣2️⃣ 啟動 ngrok（HTTP → HTTPS）=====
# !nohup ./ngrok http 6080 --region=us > ngrok.log &

# ===== 1️⃣3️⃣ 顯示可用網址 =====
time.sleep(5)
# !curl -s http://127.0.0.1:4040/api/tunnels | jq -r '.tunnels[].public_url'
