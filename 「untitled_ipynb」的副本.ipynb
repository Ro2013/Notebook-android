# %% [markdown]
# <a href="https://colab.research.google.com/github/Ro2013/Notebook-android/blob/main/%E3%80%8Cuntitled_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===== 1️⃣ 安裝桌面環境與 VNC =====
# !apt update
# !apt install -y xfce4 xfce4-goodies tightvncserver wget unzip jq

# ===== 2️⃣ 安裝 noVNC =====
# !wget https://github.com/novnc/noVNC/archive/refs/heads/master.zip
# !unzip master.zip

# ===== 3️⃣ 掛載 Google Drive =====
from google.colab import drive
drive.mount('/content/drive')  # 第一次會跳出網址，輸入授權碼即可

# ===== 4️⃣ 匯入檔案到容器（第一個錯誤手動建立 AndroidVM） =====
# !cp -r /content/drive/MyDrive/AndroidVM /content/

# ===== 5️⃣ 設定 USER 環境變數（解決第二個錯誤） =====
import os
os.environ['USER'] = 'colab'

# ===== 6️⃣ 啟動 VNC server =====
# !vncserver :1 -geometry 1280x720 -depth 24

# ===== 7️⃣ 切換目錄到 noVNC utils（解決第三個錯誤） =====
# %cd noVNC-master/utils

# ===== 正確啟動 noVNC（新版方式）=====
# %cd /content/noVNC-master

# !nohup ./utils/novnc_proxy \
  --vnc localhost:5901 \
  --listen 0.0.0.0:6080 &

# ===== 9️⃣ 等待 noVNC 完全啟動 =====
import time
time.sleep(10)  # 10 秒確保 noVNC 啟動完成

# ===== 🔟 安裝 ngrok 3 =====
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar xvzf ngrok-v3-stable-linux-amd64.tgz

# ===== 1️⃣1️⃣ 設定 ngrok token =====
# !./ngrok config add-authtoken 37SR7WypDaMORVh1v0kfoTuJv3c_652p8z5XyAujnMp3HYmzc

# ===== 1️⃣2️⃣ 啟動 ngrok 隧道 =====
# !nohup ./ngrok http 6080 --region=us > ngrok.log &

# ===== 1️⃣3️⃣ 查看生成的 HTTPS URL =====
# !sleep 5  # 等 ngrok 啟動
# !curl -s http://127.0.0.1:4040/api/tunnels | jq
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 3,917 B in 1s (4,113 B/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 6 packages can be upgraded. Run 'apt list --upgradable' to see them.
# ...
